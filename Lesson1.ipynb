# %% [markdown]
# <a href="https://colab.research.google.com/github/VitaliiBarlit/PY2021/blob/main/Lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/mount')
# Out:
# Mounted at /mount

# %%
from google.colab.files import view
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1000,1000,100)

sinx = 25*np.sin(x)/x
sin = np.sin(x)

plt.figure(1)
plt.plot(sinx)
plt.savefig('/mount/MyDrive/sinx.png')

plt.figure(2)
plt.plot(sin)
plt.savefig('/mount/MyDrive/sin1.png')
plt.show()

# %%
#google.colab.files
view('/mount/MyDrive/sin1.png')
view('/mount/MyDrive/sinx.png')
